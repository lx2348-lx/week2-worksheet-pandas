# %% [markdown]
# <a href="https://colab.research.google.com/github/lx2348-lx/week2-worksheet-pandas/blob/main/Session_2_Student_Worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Session 2 — Student Worksheet (Pandas + Plotly)
# Work in small groups. Find a CSV dataset on GitHub, load it in Colab, and adapt commands from the workbook.
# Be ready to walk through your code at the end.

# %% [markdown]
# ## Part 1 — Find a Dataset (GitHub)

# %%
excel_url = "https://github.com/kmontenegro/NYPD-Misconduct-Complaint-Database/raw/master/CCRB_database_raw.xlsx"
excel_url
# Out:
# 'https://github.com/kmontenegro/NYPD-Misconduct-Complaint-Database/raw/master/CCRB_database_raw.xlsx'

# %% [markdown]
# ## Part 2 — Load & Inspect

# %%
import pandas as pd

df = pd.read_excel(csv_url)
rows, cols = df.shape
rows, cols
# Out:
# (323911, 14)

# %% [markdown]
# ## Part 3 — Explore & Clean

# %%
df.dtypes

df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# PenaltyDesc          314033
# NYPDDisposition      312454
# Incident Date         53493
# Allegation            33683
# Board Disposition     33321
# Complaint Id          33262
# FADO Type             33262
# First Name                5
# Rank                      1
# Command                   1
# dtype: int64

# %% [markdown]
# ## Part 4 — Summarization

# %%
category_col = 'Allegation'
numeric_col = 'Unique Id'
Rename = {'Unique Id': 'Case Number'}
df = df.rename(columns=Rename)

by_cat = df.groupby("Allegation")["Case Number"].count().sort_values(ascending=False)
by_cat.head(10)
# Out:
# Allegation
# Physical force                              39164
# Word                                        27518
# Curse                                       11287
# Push/Shove                                  10425
# Threat of arrest                            10255
# Force                                       10218
# Refusal to provide name/shield number        8540
# Stop                                         8055
# Premises entered and/or searched             7971
# Punch/Kick                                   7375
# Name: Case Number, dtype: int64

# %% [markdown]
# ## Part 5 — Visualization (Pandas + Plotly)

# %%
import plotly.express as px

bar_df = by_cat.head(10).reset_index()
fig = px.bar(bar_df, x=category_col, y='Case Number', title=f'Top 10 {category_col} (interactive)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bc21d4ac-abf7-4920-9e5f-d174a03aeaae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc21d4ac-abf7-4920-9e5f-d174a03aeaae")) {                    Plotly.newPlot(                        "bc21d4ac-abf7-4920-9e5f-d174a03aeaae",                        [{"alignmentgroup":"True","hovertemplate":"Allegation=%{x}\u003cbr\u003eCase Number=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Physical force                          ","Word                                    ","Curse                                   ","Push\u002fShove                              ","Threat of arrest                        ","Force                                   ","Refusal to provide name\u002fshield number   ","Stop                                    ","Premises entered and\u002for searched        ","Punch\u002fKick                              "],"xaxis":"x","y":[39164,27518,11287,10425,10255,10218,8540,8055,7971,7375],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":" ...

# %%
import plotly.express as px

pie_df = by_cat.head(10).reset_index()
fig = px.pie(pie_df, names=category_col, values='Case Number', title=f'Top 10 {category_col} (interactive)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e6738838-d44d-4605-9baf-c3c888966c48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6738838-d44d-4605-9baf-c3c888966c48")) {                    Plotly.newPlot(                        "e6738838-d44d-4605-9baf-c3c888966c48",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Allegation=%{label}\u003cbr\u003eCase Number=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Physical force                          ","Word                                    ","Curse                                   ","Push\u002fShove                              ","Threat of arrest                        ","Force                                   ","Refusal to provide name\u002fshield number   ","Stop                                    ","Premises entered and\u002for searched        ","Punch\u002fKick                              "],"legendgroup":"","name":"","showlegend":true,"values":[39164,27518,11287,10425,10255,10218,8540,8055,7971,7375],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scat ...

# %% [markdown]
# ## Part 6 — Reflection
# - What needed adjusting when you switched datasets?
# - What was easier/harder vs the workbook?
# - What context/limitations should a policymaker know?

# %% [markdown]
# ## Part 7 — ⚡ Lightning Chart Demos — Teach-Out Instructions

# %% [markdown]
# ### What is a Lightning Demo?
# A **rapid-fire mini-presentation**: 2 minutes per group. Show **one chart** + **one insight**, not your whole notebook.
#
# ### Demo Format (2 minutes)
# 1. **Context (15 sec):** Dataset name + 1-sentence purpose.
# 2. **Chart + Insight (75–90 sec):** Show interactive Plotly chart; state one clear finding; name one wrangling step.
# 3. **Caveat or Next Step (15–30 sec):** One limitation OR next idea.
# 4. **Pass the mic (10 sec):** End with *“Any questions about our chart?”*
#
# ### Unique Angles
# - Aggregation choice (sum vs mean, raw vs normalized).
# - Data cleaning step (conversion, deduping).
# - Encoding (bar vs line vs scatter).
# - Interactivity (facet, hover, filter).
# - Comparability (per capita vs raw counts).
# - Temporal nuance (trend vs snapshot).
#
# 👉 If another group showed your angle, pick a different one.
#
# ### Flow for the Day
# - Groups present **clustered by chart type** (bars, lines, scatter, other).
# - Instructor summarizes similarities/differences after each cluster.
# - 15 groups × 2 min = ~30 minutes + transitions = ~40 minutes.
#
# ### Presenter Checklist
# - [ ] Dataset URL loads in Colab
# - [ ] Columns chosen make sense
# - [ ] One **interactive Plotly figure** with title + labels
# - [ ] Insight stated in one sentence
# - [ ] One cleaning step mentioned
#
# ### Audience Task
# After each cluster, jot 1 sentence:
# - What was **similar** across charts?
# - What was **different** (aggregation, encoding, interactivity)?
# - Which chart best supported a **policy decision**—and why?
#
# ---
# ### Quick Rubric (3 pts)
# - **Clarity of claim (1 pt)**
# - **Method fit (1 pt)**
# - **Insight/caveat (1 pt)**
# (Bonus +0.5 for meaningful interactivity)
#
# ---
# ### Minimal Code Patterns
#
# **Top-N bar:**
# ```python
# bar_df = df.groupby(category_col)[numeric_col].sum().nlargest(10).reset_index()
# fig = px.bar(bar_df, x=category_col, y=numeric_col,
#              title=f"Top 10 {category_col} by {numeric_col}")
# fig.show()
# ```
#
# **Time series:**
# ```python
# ts = (df.groupby(time_col)[numeric_col]
#         .sum()
#         .reset_index()
#         .sort_values(time_col))
# fig = px.line(ts, x=time_col, y=numeric_col, markers=True,
#               title=f"{numeric_col} over time")
# fig.show()
# ```
#
# **Scatter:**
# ```python
# fig = px.scatter(df, x=x_col, y=y_col, trendline="ols",
#                  title=f"{y_col} vs {x_col}")
# fig.show()
# ```
#
# ---
